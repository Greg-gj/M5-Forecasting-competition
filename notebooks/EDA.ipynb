# %%
import pandas as pd
import os

# %%
# Check if we are in the right place
print(f"Current Directory: {os.getcwd()}")

# Load data (using relative path)
sales = pd.read_csv('../data/sales_train_evaluation.csv', nrows=5)
print("M5 Data Sample:")
display(sales)
